# %% [markdown]
# ## Lagos Rental Property — Data Cleaning

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 30)

# %% [markdown]
# #### Load Raw Data

# %%
df = pd.read_csv("C:/Users/USER/Desktop/LRP/data/raw/all_properties.csv")
print(f"Loaded {len(df):,} raw listings")
df.head()
# Out:
# Loaded 40,694 raw listings
#                                      title  \
# 0      3 bedroom flat / apartment for rent
# 1      2 bedroom flat / apartment for rent
# 2      2 bedroom flat / apartment for rent
# 3  3 bedroom semi-detached duplex for rent
# 4      3 bedroom flat / apartment for rent
#
#                                             location  \
# 0                        Victoria Island (VI), Lagos
# 1  5mins From Unilag Close To Yabatech In Secure ...
# 2                        Banana Island, Ikoyi, Lagos
# 3                        Lekki Phase 1, Lekki, Lagos
# 4                        Lekki Phase 1, Lekki, Lagos
#
#                            spec                  price  \
# 0  3 Beds | 3 Baths | 4 Toilets  ₦40,000,000 per annum
# 1                        2 Beds     ₦500,000 per annum
# 2  2 Beds | 2 Baths | 3 Toilets  ₦60,000,000 per annum
# 3  3 Beds | 3 Baths | 4 Toilets  ₦25,000,000 per annum
# 4  3 Beds | 3 Baths | 4 Toilets  ₦25,000,000 per annum
#
# ...

# %%
def missing(df):
    missing = df.isnull().sum()
    missing_percent = (missing / len(df)) * 100
    missing_df = pd.DataFrame({
        'Missing Count': missing,
        'Missing Percentage': missing_percent
    })
    return round(missing_df[missing_df['Missing Count'] > 0], 2)

missing(df)
# Out:
#              Missing Count  Missing Percentage
# title                   95                0.23
# location                95                0.23
# spec                  4976               12.23
# price                   95                0.23
# description            102                0.25
# features             11357               27.91

# %% [markdown]
# #### Cleaning & Filtering Functions

# %% [markdown]
# ##### Sale / Non-Rental Filter

# %%
# Filter out: for-sale listings, shortlets, and non-residential types (office, shop, etc.)

# Regex for non-rental keywords in title
non_rental = re.compile(
    r'\b('
        r'office|office space|shop|warehouse|factory|plaza|'
        r'hotel|church|school|filling station|co-working'
    r')\b', re.IGNORECASE
)

# Regex for sale/shortlet in title or description
sale_desc = re.compile(
    r'\b('
        r'for sale|outright sale|asking price|sale price|purchase price|'
        r'investor|investment opportunity|buy now|'
        r'shortlet|short let|short-let|holiday|vacation rental'
    r')\b', re.IGNORECASE
)

# Regex that matches rental-period suffixes in price strings
rental_suffix = re.compile(
    r'/(year|annum|month|monthly|annually|p\.a)'
    r'|per\s+(annum|year|month|monthly|annually)'
    r'|p\.a\b'
    r'|\bmonthly\b'
    r'|\bannually\b',
    re.IGNORECASE
)


def is_for_sale(row):
    """Return True if a listing looks like a sale, shortlet, or commercial listing."""
    title = str(row.get('title', '') or '').strip().lower()
    desc  = str(row.get('description', '') or '').strip().lower()
    price = str(row.get('price', '') or '').strip()

    # Non-residential title
    if non_rental.search(title):
        return True

    # Sale/shortlet language in title
    if sale_desc.search(title):
        return True

    # If the price lacks rental suffix likely a sale price
    if price and not rental_suffix.search(price):
        return True

    return False

# %% [markdown]
# ##### Property Type Classification

# %%
# Map title keywords to canonical property types.

type_map = [
    ('semi-detached',  'Duplex'),
    ('semi detached',  'Duplex'),
    ('terrace',        'Duplex'),
    ('maisonette',     'Duplex'),
    ('penthouse',      'Multi storey'),
    ('villa',          'Duplex'),
    ('townhouse',      'Multi storey'),
    ('duplex',         'Duplex'),
    ('storey building','Duplex'),
    ('detached',       'Duplex'),
    ('self contain',   'Apartment'),
    ('self-contain',   'Apartment'),
    ('self contained', 'Apartment'),
    ('single room',    'Apartment'),
    ('mini flat',      'Apartment'),
    ('miniflat',      'Apartment'),
    ('mini-flat',      'Apartment'),
    ('room and parlour','Apartment'),
    ('apartment',      'Apartment'),
    ('flat',           'Apartment'),
    ('house',          'Apartment'),
    ('bungalow',       'Apartment'),
    ('studio',         'Apartment'),
    ('bedroom',        'Apartment'),
]

# Filtering out the non-residential properties
commercial = re.compile(
    r'\b(office|commercial|shop|warehouse|factory|plaza|hotel|'
    r'church|school|filling station|co-working|land)\b',
    re.IGNORECASE
)


def get_property_type(title):
    """Classify a listing title into a canonical property type"""
    if pd.isna(title) or not str(title).strip():
        return None
    t = str(title).lower()

    # Check commercial first
    if commercial.search(t):
        return None

    for keyword, prop_type in type_map:
        if keyword in t:
            return prop_type

    return None

# %% [markdown]
# ##### Bedroom Extraction from Title

# %%
def extract_beds_from_title(title):
    """Extracting no of bedrooms from listing title for properties with no values in specs"""
    if pd.isna(title):
        return np.nan
    t = str(title).lower()

    # Self-contain, mini flat, studio = 1 bedroom
    if any(kw in t for kw in ['studio', 'self contain', 'self-contain',
                              'selfcontain', 'single room', 'mini flat',
                              'room and parlour']):
        return 1

    m = re.search(r'(\d+)\s*(?:bed|bedroom|br\b)', t)
    return int(m.group(1)) if m else np.nan

# %% [markdown]
# ##### Location → Area Extraction

# %%
def extract_area(location):
    """Extract area name from location string"""
    if pd.isna(location):
        return np.nan
    s = str(location).strip()

    # Removing trailing ', Lagos' or ' Lagos'
    s = re.sub(r',?\s*Lagos\s*$', '', s, flags=re.IGNORECASE)
    s = s.strip().rstrip(',')

    if not s:
        return np.nan

    parts = [p.strip().title() for p in s.split(',') if p.strip()]
    if len(parts) >= 2:
        return f"{parts[-2]} {parts[-1]}"
    elif len(parts) == 1:
        return parts[0]
    
    return np.nan

# %% [markdown]
# ##### Spec Parsing

# %%
def parse_spec(spec):
    """Parse spec string like '3 Beds | 2 Baths | 3 Toilets' into dictionary"""
    result = {'bedrooms': np.nan, 'bathrooms': np.nan, 'toilets': np.nan}
    if pd.isna(spec) or str(spec).strip().upper() == 'N/A':
        return result
    for part in str(spec).split('|'):
        part = part.strip().lower()
        m = re.search(r'(\d+)', part)
        if not m:
            continue
        n = int(m.group(1))

        if 'bed' in part: result['bedrooms'] = n
        elif 'bath' in part: result['bathrooms'] = n
        elif 'toilet' in part: result['toilets'] = n
    return result

# %% [markdown]
# ##### Price Cleaning

# %%
def clean_price(price_str):
    """Parse price string into annual rent & monthly prices are multiplied by 12"""
    if pd.isna(price_str):
        return np.nan
    s = str(price_str).lower().strip()

    # Extract numeric part
    num_str = re.sub(r'[^\d.]', '', s.split('/')[0])
    if not num_str:
        return np.nan
    try:
        val = float(num_str)
    except ValueError:
        return np.nan

    # Multiply monthly prices by 12
    if re.search(r'/month|/monthly|per month|\bmonthly\b', s):
        val *= 12

    # Sanity bounds: N500k – N500m / year
    if val < 500_000 or val > 500_000_000:
        return np.nan

    return val

# %% [markdown]
# ##### Amenity Extraction

# %%
# Amenity keyword patterns — scans description + features text
amenities = {
    'has_pool':       re.compile(r'pool|swimming',             re.I),
    'has_gym':        re.compile(r'\bgym\b|fitness',           re.I),
    'has_parking':    re.compile(r'parking|garage',            re.I),
    'has_bq':         re.compile(r'\bbq\b|boys.quarter',       re.I),
    'has_elevator':   re.compile(r'elevator|lift',             re.I),
    'is_newly_built': re.compile(r'newly.built|brand.new',     re.I),
    'is_furnished':   re.compile(r'\bfurnished\b',             re.I),
    'is_serviced':    re.compile(r'serviced|service.charge',   re.I),
    'has_security':   re.compile(r'security',                  re.I),
    'has_generator':  re.compile(r'generator',                 re.I),
    'has_ac':         re.compile(r'air.condition|\bac\b',      re.I),
    'has_wifi':       re.compile(r'wi-?fi|internet',           re.I),
    'has_water':      re.compile(r'water supply|borehole|water.tank', re.I),
}


def extract_amenities(desc, feat):
    """Scan description + features for amenity keywords"""
    text = (str(desc) if pd.notna(desc) else '') + ' ' + (str(feat) if pd.notna(feat) else '')
    text = text.lower()
    return {k: int(bool(pat.search(text))) for k, pat in amenities.items()}

# %% [markdown]
# ---
# ## Apply Pipeline

# %%
data = df.copy()

# Drop exact duplicates
before = len(data)
data.drop_duplicates(inplace=True)
print(f"Dropped {before - len(data):,} exact duplicates = {len(data):,} remaining")

# Classify property type
data['property_type'] = data['title'].apply(get_property_type)
non_res = data['property_type'].isna().sum()
data = data[data['property_type'].notna()].copy()
print(f"Removed {non_res:,} non-residential/unrecognised = {len(data):,} remaining")

# Filter out sale/shortlet listings
sale_mask = data.apply(is_for_sale, axis=1)
data = data[~sale_mask].copy()
print(f"Removed {sale_mask.sum():,} sale/shortlet listings = {len(data):,} remaining")

# Clean price 
data['price_annual'] = data['price'].apply(clean_price)
no_price = data['price_annual'].isna().sum()
data.dropna(subset=['price_annual'], inplace=True)
print(f"Dropped {no_price:,} rows with invalid price = {len(data):,} remaining")
print(f"Price range: N{data['price_annual'].min():,.0f} – N{data['price_annual'].max():,.0f}/year")
# Out:
# Dropped 7,131 exact duplicates = 33,563 remaining
# Removed 3,275 non-residential/unrecognised = 30,288 remaining
# Removed 1,624 sale/shortlet listings = 28,664 remaining
# Dropped 335 rows with invalid price = 28,329 remaining
# Price range: N500,000 – N500,000,000/year

# %%
# Parse specs = bedrooms, bathrooms, toilets (with imputation)
spec_parsed = data['spec'].apply(parse_spec).apply(pd.Series)
data[['bedrooms', 'bathrooms', 'toilets']] = spec_parsed

# Extract bedrooms from title if missing
data['_beds_title'] = data['title'].apply(extract_beds_from_title)
data['bedrooms'] = data['bedrooms'].fillna(data['_beds_title'])
data.drop(columns=['_beds_title'], inplace=True)

# Impute missing bathrooms: assume bathrooms ≈ bedrooms for residential types
fill_bath = data['bedrooms'].notna() & data['bathrooms'].isna()
data.loc[fill_bath, 'bathrooms'] = data.loc[fill_bath, 'bedrooms']

# Group-median imputation by property type, then global median fallback
for col in ['bedrooms', 'bathrooms', 'toilets']:
    type_med = data.groupby('property_type')[col].median()
    data[col] = data[col].fillna(data['property_type'].map(type_med))
    data[col] = data[col].fillna(data[col].median())

# Clip to plausible ranges
data['bedrooms']  = data['bedrooms'].clip(1, 8)
data['bathrooms'] = data['bathrooms'].clip(1, 8)
data['toilets']   = data['toilets'].clip(1, 10)

print("Spec summary:")
print(data[['bedrooms','bathrooms','toilets']].describe().round(1))
# Out:
# Spec summary:
#        bedrooms  bathrooms  toilets
# count   28329.0    28329.0  28329.0
# mean        2.8        2.9      3.6
# std         1.3        1.4      1.5
# min         1.0        1.0      1.0
# 25%         2.0        2.0      3.0
# 50%         3.0        3.0      4.0
# 75%         4.0        4.0      5.0
# max         8.0        8.0     10.0

# %%
# Extract area from location
data['area'] = data['location'].apply(extract_area)
print(f"Unique areas: {data['area'].nunique():,}")
print(f"Top 10 areas:\n{data['area'].value_counts().head(10)}")

# Extract amenity flags
amenity_rows = [extract_amenities(row['description'], row['features']) for _, row in data.iterrows()]
amenity_df = pd.DataFrame(amenity_rows, index=data.index)
data = pd.concat([data, amenity_df], axis=1)
print(f"\nExtracted {len(amenity_df.columns)} amenity flags")

# Drop near-duplicates
before = len(data)
data.drop_duplicates(subset=['title', 'price_annual', 'area'], inplace=True)
print(f"Dropped {before - len(data):,} near-duplicates = {len(data):,} remaining")

print(f"Final cleaned dataset: {len(data):,} rental listings")
# Out:
# Unique areas: 2,266
# Top 10 areas:
# area
# Lekki Phase 1 Lekki           3076
# Ikate Lekki                   1166
# Ikota Lekki                   1099
# Sangotedo Ajah                 785
# Banana Island Ikoyi            711
# Osapa Lekki                    654
# Old Ikoyi Ikoyi                553
# Oniru Victoria Island (Vi)     486
# Ologolo Lekki                  484
# Ikate Elegushi Lekki           400
# Name: count, dtype: int64
#
# Extracted 13 amenity flags
# Dropped 14,843 near-duplicates = 13,486 remaining
# Final cleaned dataset: 13,486 rental listings

# %% [markdown]
# ---
# #### Quality Check

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].hist(np.log10(data['price_annual']), bins=40, color='steelblue', edgecolor='white', alpha=0.85)
axes[0].set_title('Annual Rent Distribution (log10)', fontweight='bold')
axes[0].set_xlabel('logPrice(N/year)')
axes[0].set_ylabel('Count')

pt = data['property_type'].value_counts()
axes[1].barh(pt.index, pt.values, color='coral', edgecolor='white', alpha=0.85)
axes[1].set_title('Listings by Property Type', fontweight='bold')
axes[1].set_xlabel('Count')

beds = data['bedrooms'].value_counts().sort_index()
axes[2].bar(beds.index.astype(int), beds.values, color='mediumseagreen', edgecolor='white', alpha=0.85)
axes[2].set_title('Bedroom Distribution', fontweight='bold')
axes[2].set_xlabel('Bedrooms')
axes[2].set_ylabel('Count')

plt.tight_layout()
plt.show()

# Price quartiles
print("Price quartiles (N):")
for q, v in data['price_annual'].quantile([0.25, 0.50, 0.75, 0.90]).items():
    print(f"Q{int(q*100):3d}: {v:>15,.0f}")

# Missing values check
print("\nRemaining missing values:")
print(missing(data))
# Out:
# Price quartiles (N):
# Q 25:       3,500,000
# Q 50:       8,000,000
# Q 75:      20,000,000
# Q 90:      45,000,000
#
# Remaining missing values:
#              Missing Count  Missing Percentage
# spec                   855                6.34
# description              4                0.03
# features              3483               25.83
# area                  4914               36.44

# %% [markdown]
# ---
# #### Save Cleaned Data

# %%
cols = [
    'title', 'area', 'property_type', 'price_annual',
    'bedrooms', 'bathrooms', 'toilets',
    'has_pool', 'has_gym', 'has_parking', 'has_bq', 'has_elevator',
    'is_newly_built', 'is_furnished', 'is_serviced',
    'has_security', 'has_generator', 'has_ac', 'has_wifi', 'has_water'
]

df_clean = data[cols].copy()
output_path = "C:/Users/USER/Desktop/LRP/data/processed/properties_cleaned.csv"
df_clean.to_csv(output_path, index=False)
print(f"Saved {len(df_clean):,} cleaned listings = {output_path}")
# Out:
# Saved 13,486 cleaned listings = C:/Users/USER/Desktop/LRP/data/processed/properties_cleaned.csv

# %%
missing(df_clean)
# Out:
#       Missing Count  Missing Percentage
# area           4914               36.44
